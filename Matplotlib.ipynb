# %%
 from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3,4],[2,4,6,8])
plt.show()

# %%
plt.plot([1,3,5,7,9],[3,1,8,5,3])
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [4, 5, 7, 2, 1]
plt.plot(x,y)
plt.title('Graph')
plt.xlable('X')
plt.ylabel('Y')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 4>()
#       2 y = [4, 5, 7, 2, 1]
#       3 plt.plot(x,y)
# ----> 4 plt.title('Graph')
#       5 plt.xlable('X')
#       6 plt.ylabel('Y')
#
# TypeError: 'str' object is not callable

# %%
x=[1,4,6,8,9]
y=[4,6,8,2,3]
plt.plot(x,y)
plt.title('info')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 4>()
#       2 y=[4,6,8,2,3]
#       3 plt.plot(x,y)
# ----> 4 plt.title('info')
#       5 plt.xlabel('x axis')
#       6 plt.ylabel('y axis')
#
# TypeError: 'str' object is not callable

# %%
from matplotlib import style as sty
